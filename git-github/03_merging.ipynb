# %% [markdown]
# # 1 Git functions
#
# - Fast Forward Merges
# - Git Merge & Merge Commits
# - Resolving Merge Conflicts

# %% [markdown]
# # 2 Workshop
#
# Branches makes it super easy to work within self-contained contexts, but often we want to incorporate changes from one branch to another!
#
# We can do this using the `git merge` command
#
# **We merge branches, not specific commits**
# **We always merge to the current HEAD branch**
#
#
# To merge, follow these basic steps:
# 1. Switch to or checkout the branch you want to merge the changes into (the receiving branch)
# 2. Use the `git merge` command to merge changes from specific branch into the current branch
# `git switch master`
# `git merge bugfix`
#
#
# #### 2.1
# **Fast-forward merges** literally move your main branch's tip forward to the end of your feature branch.
#
#
#
# #### 2. Commands:
# - [`git merge <branch-name>`](https://git-scm.com/docs/git-merge) you have to be in the branch you want to merge the changes into.
#
#
# #### 2. Instructions
# #####  1. Discuss what necessary stuff we have to do?
# #####  2. touch index.txt
# #####  3. touch models.txt
# #####  4. git branch
# #####  5. git commit -am 'first commit'
# #####  6. git add .
# #####  7. git commit -am 'create files: index and models'
# #####  8. git log
# #####  9. git branch
# ##### 10. add 'linear regression' to models file
# ##### 11. git commit -am 'add linear regression (to models file)'
# ##### 12. git log --oneline
# ##### 13. git branch
# ##### 14. (how to create new brach?) create and switch to a new branch `read-about`
# ##### 15. add to models file line: 'logistic regression'
# ##### 16. git commit -am 'add logistic regression (to models file)'
# ##### 17. add to models file line: 'lasso regression'
# ##### 16. git commit -am 'add lasso regression (to models file)'
# ##### 17. git log --oneline
# ##### 18. git branch
# ##### 19. git switch main (master)
# ##### 20. git merge read-about
# ##### 21. git status
# ##### 22. git branch
# ##### 23. git log --oneline
# ##### 24. git switch read-about
# ##### 25. git switch -c find-info-about
# ##### 26. add line 'svm classification' to file models
# ##### 27. commit -am  'add svm classification'
# ##### 28. add line 'svm regression' to file models
# ##### 29. commit -am  'add svm regression'
# ##### 30. git status
# ##### 31. git branch
# ##### 32. git log --oneline
# ##### 33. Q: If we switch to other branch and `git merge find-info-about` what type of merging it will be?
# ##### 33. git switch read-about
# ##### 34. touch ideas.txt (add new file)
# ##### 35. git add ideas.txt
# ##### 36. add line ideas file: find examples of code with linear regression model
# ##### 37. commit -am  'add find example of linear regression code'
# ##### 38. git status
# ##### 39. git log --oneline
# ##### 40. git branch
# ##### 41. git merge find-info-about
# ##### 42. git status
# ##### 43. git log --oneline
#
# ##### 44. git switch main (master)
# ##### 45. delete all, add a line 'use linear regression' to file models
# ##### 46. commit -am  'add use lr' (?)
# ##### 47. add a line 'use logistic regression' to file models
# ##### 48. commit -am  'add use lr' (?)
# ##### 49. git status
# ##### 50. git log --oneline
# ##### 51. git merge find-info-about

# %% [markdown]
# # 3 Exercise
#
# Start by creating a new repo.  Make a file or two in the repo for you to work on.
#
#
# If you need some inspiration, I'll be working in a file called `program_languages.txt`. It will contain the best programming languages to learn in 2023.
#
# ### Part 1: Fast Forward Merge
#
# **Your goal is to generate a fast forward merge. Demonstrate that you understand how FF merges work by creating one on your own!**
#
# Make a new branch. Do some work in the repo such that when you merge the new branch into master, it results in a fast forward merge.  Merge that branch into master and see if you were right!
#
#
# ### Part 2: Merge Commit (No Conflicts)
#
# Your goal is to generate a merge commit with NO MERGE CONFLICTS.
#
# Create a new branch. Make some changes to the repo such that when you merge the new branch into master, it results in a merge commit.  The merge should not result in any conflicts. Merge that branch into master and see if you were right!
#
# ### Part 3: Conflicts!
#
# Your goal is to generate merge a conflict!
#
# Create a new branch.  Make some changes to the repo such that when you merge the new branch into the master branch, it results in a merge conflict. Merge that branch into master and see if you were right! Resolve the conflict!

# %% [markdown]
# # 4 Repeat exercise with your data in 2-3 days
