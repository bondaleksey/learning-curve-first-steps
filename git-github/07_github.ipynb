# %% [markdown]
# # 1 Intro
#
# ##
#
# ## 1.1 Event goal & plan
# - Part 1: Cloning others repos
#     - registering for Github & Setting UP SSH keys
# - Part 2: Connecting Git and Github
#     - Option 1. Push your local repo to empty github.
#     - Option 2. Create GitHub Repo and clone.
# - Part 3: Collaboration on Github
#     - Fork and push your code.
#     - Clone this repo to local git, make changes in Github and local repo, and resolve conflict by adding new parts. Pull request it.
# - Part 4: Your portfolio on Github
# - Optional: Summarize three git-from-zero events.
#
#
# ## 1.2 About
#
# Github is a hosting platform for git repositories.
# You can:
# - put your own Git repos on Github,
# - access them from anywhere,
# - share them with people around the world.
# *Github provides additional collaboration features that are not native to Git.*
#
# There are many of competing tools that provide similar hosting and collaboration features, including:
# - **GitLab**,
# - **GBiyBucket**,
# - **Gerrit**.
#
#
# Github offers its basic service for free!
#
# ## 1.3 Permissions to clone?
# Anyone can clone a repository from Github, provided the repo is public.
# You do not need to be an owner or collaborator to clone the repo locally to your machine.
# You just need the URL from Github.
#
# Pushing up your own changes to the Github repo ... that's
# another story entirely! You need permission to do that!
#
# ### Take the first 10 steps in the instructions set
#
# ## 1.4 Connecting to GitHub with SSH
# You need to be authenticated on Github to do certain operations, like pushing up code from your local machine.
# Your terminal will prompt you every single time for your Github email and password, unless ...
# You generate and configure an SSH key! Once configured, you can connect to Github without having to supply your username/password.
#
# [github-ssh](https://docs.github.com/en/authentication/connecting-to-github-with-ssh)
#
#
# 1. [Checking for existing SSH keys](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/checking-for-existing-ssh-keys)
#
# 2. [Generating a new SSH key and adding it to the ssh-agent](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/generating-a-new-ssh-key-and-adding-it-to-the-ssh-agent)
#
# 3. [Add the SSH key to your Github account](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/adding-a-new-ssh-key-to-your-github-account)
#
#
# ## 1.5 How to connect Github and Git
#
# ### Option 1: Existing Repo (You have local repo and want to connect it with Github)
#
# If you already have an existing repo locally that you want to get on Github
# - Create a new repo (empty = without files) on github
# - Connect your local repo (add a remote)
# - Push up your changes to Github
#
# ### Take 10-30 steps in the instructions set
#
# ### Option 2: Start From Scratch (You don't have local repo,  and want to start from Github)
#
# If you haven't begun work on your local repo, you can ...
# - Create a brand new repo on Github
# - clone it down to your machine
# - do some work locally
# - Push up your changes to Github
#
#
# ### Take 30-40 steps in the instructions set
#
#
#
# ## 1.XX We will use functions
#
# - [git clone](https://git-scm.com/docs/git-clone) to get a local copy of an existing repository
#     - git clone <url> -> Git will retrieve all the files associated with the repository and will copy them to your local machine. In addition, Git initializes a new repository on your machine, giving you access to the full Git history of the cloned project.
#
# - [git remote](https://git-scm.com/book/en/v2/Git-Basics-Working-with-Remotes), [ru](https://git-scm.com/book/ru/v2/%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B-Git-%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0-%D1%81-%D1%83%D0%B4%D0%B0%D0%BB%D1%91%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8-%D1%80%D0%B5%D0%BF%D0%BE%D0%B7%D0%B8%D1%82%D0%BE%D1%80%D0%B8%D1%8F%D0%BC%D0%B8)
#     - git remote -v ->
#     - git remote add name <url> = git remote add origin <url> -> origin is a conventional Git remote name, but it is not at all special. It's just a nme for a URL. When we clone a Github repo, the default remote name setup for us is called origin. You can change it. Most people leave it.
#     - git remote show origin ->
#
# - [git pull]()
#     - git pull
#
#
# - [git push](https://git-scm.com/docs/git-push)
#     - git push <remote> <branch>
#     - git push -> if you already set up origin and ... then you can just do git push, but when you just set origin

# %% [markdown]
# # 2 Workshop
#
# # Part 1: Cloning others repos
#
# #####  1 mkdir cloning (make folder )
# #####  2 cd cloning
# #####  3 git status (check are you in git folder?)
# #####  4 git clone https://github.com/poteto/hiring-without-whiteboards.git
# #####  5 git log --oneline (look in gitkraken)
# #####  6 cd .. (exit from folder)
# #####  7 git status (check are you in git folder?)
# #####  8 git clone https://gitlab.com/gitlab-tests/sample-project
# #####  9 git log --oneline (look in gitkraken)
#
# # Part 2: Connecting Git and Github
# ## --- Option-1 Connect existing repo with Git ---
# ##### 10 mkdir git-event-3-op1 # make folder git-event-3-option-1
# ##### 11 cd git-event-3-option-1
# ##### 12 git status (check that we are not in git repo)
# ##### 13 git init
# ##### 14 touch README.md
# ##### 15 git add README.md
# ##### 16 git commit -m 'create readme file'
# ##### 17 add few lines to README file
# ##### 18 git commit -m 'create readme file'
# ##### 19 Go to github and create a new repository with name 'github-demo-option-1' with README.md file
#
# #### At this moment we usually use commands:
# git remote add origin https://github.com/your-github-name/git-repo.git
# git branch -M main
# git push -u origin main
#
#
# ##### 20 Go to git
# ##### 21 git remote
# ##### 22 git remote add origin https://github.com/bondaleksey/github-demo-option-1.git
# ##### 23 git remote
# ##### 24 git remote show origin
# #####    git push -u origin main
#
# ## Example when we have unrelated histories
#
# ##### 25 git branch
# ##### 26 git branch -M main (in git we have "master" but in github we have "main")
# #####    git push -u origin main
# ##### 27 git pull -u origin main (fatal: refusing to merge unrelated histories)
# ##### 28 git pull origin main --allow-unrelated-histories
#
# #### (resolve conflicts)
# ##### 29 make changes in the conflict files (README.md) and save them
# ##### 30 git add .
# ##### 31 git commit -m 'merge '
# ##### 32 git push -u origin main
#
#
#
#
#
# ## --- Option-2 Start From Scratch ---
#
# ##### Create new Github repo: github-demo-option-2.git
# !for me (github-forking-test.git)
# ##### add file README.md
# ##### add line to file README.md and commit it
# ##### go to git folder
# ##### git status
# ##### git clone <url> = '.../github-demo-option-2.git'
# ##### cd github-demo-option-2
# ##### git status
# ##### git log
# ##### git remote
# ##### git remote show origin
#
#
# # Make README.md file about yourself
#
# # Part 3: Collaboration on Github
# ### --- Fork and push your code ---
# ##### Go to github repo github-forking-test and fork it
# Example: fork repo [Noah readme project](https://github.com/noahgift/noahgift)
# ##### add you nickname/name to README.md
# ##### go to pull requests section and make pull request
# ### --- Apply to the project and push your code ---
# ##### Clone this repo to local git,
# ##### Make changes in Github by creating new file 'your-name.txt'
# ##### Make changes in local repo by adding lines to README file
# ##### Resolve conflict by adding new parts (git status git log --oneline)
# ##### Make changes to github and local git that will cause a conflict.
# ##### add local changes and pull github
# ##### Resolve conflict by adding new parts (git status git log --oneline)
#
#
# # Part 4: Your portfolio on Github
# ##### [How to: 'README.md'](https://docs.github.com/en/account-and-profile/setting-up-and-managing-your-github-profile/customizing-your-profile/managing-your-profile-readme)
# ##### [Example: Wes ))](https://github.com/wesm),  [github repo](https://github.com/wesm/wesm)
# ##### [Example: Noah](https://github.com/noahgift)
# ##### [Example: awesome-github-profile-readme](https://github.com/abhisheknaiidu/awesome-github-profile-readme)
#
# ##### [How to: 'github.io'](https://pages.github.com/)
# ##### [Example: Youtube 11 mins](https://www.youtube.com/watch?v=1aXk2RViq3c)
# ##### [Example: *archd3sai* github project ](https://github.com/archd3sai/Portfolio)
# ##### [Example: *rodrigo-arenas* github project](https://github.com/rodrigo-arenas/portfolio)

# %% [markdown]
# # 3 Exercise

# %% [markdown]
# # 4 Repeat exercise with your data in 2-3 days
